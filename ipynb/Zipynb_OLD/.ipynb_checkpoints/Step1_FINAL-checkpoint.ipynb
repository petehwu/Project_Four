# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in /opt/conda/lib/python3.6/site-packages

# %%
cd '/home/jovyan/lib'
# Out:
# /home/jovyan/lib

# %%
#import psycopg2 as pg2
#from psycopg2.extras import RealDictCursor
import re
import requests
import db_helper as db
#https://www.mediawiki.org/wiki/API:Search_and_discovery

# %%
connection, cursor = db.connect_to_db()

# %%
def cleaner(text):
    text = re.sub('[A-Z]\\n',' ', text)
    text = re.sub('{.*}', '', text)
    text = re.sub('\s\s', ' ', text)
    text = re.sub('[^a-zA-Z ]',' ',text)
    text = re.sub('\\t', ' ', text)
    text = re.sub('\s\s', ' ', text)
    #text = re.sub('[\n]','', text)
    ##text = re.sub('{[A-Za-z]}','', text)
    #text = ' '.join(i.lemma_ for i in nltk(text)
    #                if i.orth_ not in stop)
    #text = ' '.join(text.split())
    return text

# %%
##only run this block if you want to drop all your tables

drop_table = """
BEGIN;

COMMIT;
"""
cursor.execute(drop_table)

# %%
#tmp_sql = """
#BEGIN;
#DROP TABLE CATEGORY_DATA;
#COMMIT;
#CREATE TABLE CATEGORY_DATA (
#        MAINCATEGORYID INTEGER ,
#        PAGEID INTEGER,
#        SUBCATEGORY TEXT,
#        LEVEL INTEGER);
#COMMIT;
#"""
#cursor.execute(tmp_sql)

# %%
#only run this block if you need to create the tables
#create_table = """
#BEGIN;
#CREATE TABLE PAGE_INFO (
#        PAGEID INTEGER PRIMARY KEY,
#        TITLE TEXT);
#        
#CREATE TABLE CATEGORY_INFO (
#        CATEGORYID SERIAL PRIMARY KEY,
#        CATEGORY_NAME TEXT);
#        
#CREATE TABLE PAGE_DATA (
#        PAGEID INTEGER PRIMARY KEY,
#        TITLE TEXT,
#        PAGE_TEXT TEXT );
#        
#CREATE TABLE CATEGORY_DATA (
#        MAINCATEGORYID INTEGER ,
#        PAGEID INTEGER,
#        SUBCATEGORY TEXT,
#        LEVEL INTEGER);
#
#COMMIT;
#"""
#cursor.execute(create_table)

# %%
clear_table = """
BEGIN;
DELETE FROM PAGE_INFO;
COMMIT;
DELETE FROM PAGE_DATA;
COMMIT;
DELETE FROM CATEGORY_DATA;
COMMIT;
DELETE FROM CATEGORY_INFO;
COMMIT
"""
cursor.execute(clear_table)

# %%
def generate_category(category):
    '''
    format a category for insertion in to a wikipedia api call
    '''
    category = re.sub('\s','_',category)
    category = category.lower()
    #print(category)
    return category

# %%
def generate_query(category):
    '''
    Format an api call for requests
    '''
    query = """
            http://en.wikipedia.org/w/api.php?
            action=query&
            format=json&
            list=categorymembers&
            cmtitle=Category:{}& 
            cmlimit=max
            """.format(generate_category(category))
    query = re.sub('\s','',query)
    return query

# %%
def get_page_ids(category, level=0):
    #insert record into the Category Table and get the categoryID
    category = generate_category(category)
    #category = category.lower()
    cursor.execute("SELECT CATEGORYID FROM CATEGORY_INFO where category_name = '{}';".format(category))
    cat_id = cursor.fetchall()
    if not cat_id:
        insert_category = """
                BEGIN;
                INSERT INTO CATEGORY_INFO (CATEGORY_NAME) VALUES ('{}');
                COMMIT;
                    """.format(category.lower())
        cursor.execute(insert_category)
    cursor.execute("SELECT CATEGORYID FROM CATEGORY_INFO where category_name = '{}';".format(category))
    cat_id = cursor.fetchall()
    cat_id = cat_id[0]['categoryid']
    get_wikipedia_page_ids(category, cat_id, level)
    
    #pass CategoryID into recursive function to get pageID 
    #query = generate_query(category)

# %%
def get_wikipedia_page_ids(category, cat_id, level = 0):
    #base_url = 'https://en.wikipedia.org/w/api.php'
    #action = '?action=query'
    #parameters = '&format=json&list=categorymembers&cmtitle=Category:' + category + '&cmlimit=max'
    #rich_url = base_url+action+parameters
    #print(rich_url)
    #response_url = requests.get(rich_url)
    #rich_url = generate_query(category)
    #print( generate_query(category))
    response_url = requests.get(generate_query(category))
    #response_url
    response_url.json()
    id_list = response_url.json()['query']['categorymembers']
    for x in id_list:
        pageid = x['pageid']
        title = x['title']
        title = title.replace("'", '"')
        if ('Category:' not in title):
            #check to see if page already exists.  If it does do not insert again
            cursor.execute("""SELECT PAGEID FROM PAGE_INFO WHERE PAGEID = {};""".format(pageid))
            page_exist = cursor.fetchall()
            if not page_exist:
                insert_stmt = """
                       BEGIN;
                       INSERT INTO PAGE_INFO VALUES ({},'{}');
                       COMMIT;
                   """.format(pageid, title)
                cursor.execute(insert_stmt)
            #from here, insert category_id and page_id into category_data table
            rec_exist = cursor.execute("""SELECT MAINCATEGORYID FROM CATEGORY_DATA WHERE MAINCATEGORYID = {} AND PAGEID = {};""".format(cat_id, pageid))
            if not rec_exist:
                insert_stmt = """
                        BEGIN;
                        INSERT INTO CATEGORY_DATA (MAINCATEGORYID, PAGEID, LEVEL) VALUES ('{}', {}, {});
                        COMMIT;
                    """.format(cat_id, pageid,level)
                cursor.execute(insert_stmt)
        else:
            # if level > 0 decrease level by 1 and then make recursive call using sub-category as category 
            if level:
                #print('here')
                level -=1
                sub_cat = title.replace('Category:', '')
                insert_subcat = """
                    BEGIN;
                    INSERT INTO CATEGORY_DATA (MAINCATEGORYID, PAGEID, SUBCATEGORY, LEVEL ) VALUES ({}, {}, '{}',{});
                    COMMIT;
                    """.format(cat_id, pageid, sub_cat, level)
                cursor.execute(insert_subcat)
                get_wikipedia_page_ids(sub_cat, cat_id, level)
                level +=1

# %%
clear_table = """
BEGIN;
DELETE FROM PAGE_INFO;
COMMIT;
DELETE FROM PAGE_DATA;
COMMIT;
DELETE FROM CATEGORY_DATA;
COMMIT;
DELETE FROM CATEGORY_INFO;
COMMIT
"""
cursor.execute(clear_table)

# %%
clear_table = """
BEGIN;
DELETE FROM PAGE_INFO;
COMMIT;
DELETE FROM CATEGORY_DATA;
COMMIT;
"""
cursor.execute(clear_table)

# %%
get_page_ids('Business Software', 2)

# %%
select_stmt = """
SELECT count(*) FROM page_info limit 10;
"""
cursor.execute(select_stmt)
cursor.fetchall()
# Out:
# [{'count': 3876}]

# %%
select_stmt = """
SELECT * FROM category_info limit 10;
"""
cursor.execute(select_stmt)
cursor.fetchall()
# Out:
# [{'category_name': 'machine learning', 'categoryid': 42},
#  {'category_name': 'business software', 'categoryid': 43},
#  {'category_name': 'machine_learning', 'categoryid': 44},
#  {'category_name': 'business_software', 'categoryid': 45}]

# %%
select_stmt = """
SELECT * FROM category_data WHERE LEVEL = 1  and maincategoryid = 45  limit 50;
"""
cursor.execute(select_stmt)
cursor.fetchall()
# Out:
# [{'level': 1,
#   'maincategoryid': 45,
#   'pageid': 20727104,
#   'subcategory': 'Administrative software'},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 26722741, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 11595731, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 3277841, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 13589812, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 4102341, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 26137900, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 2399838, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 1191446, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 6603087, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 22162830, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 22112879, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 11984942, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 49677616, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 21586721, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 26257864, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 41332176, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 28472181, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 49478757, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 21521968, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 54493227, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 32166425, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 40400354, 'subcategory': None},
#  {'level': 1,
#   'maincategoryid': 45,
#   'pageid': 17799618,
#   'subcategory': 'Business simulation games'},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 4171371, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 21362278, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 20274682, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 43302474, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 13767273, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 47155408, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 444481, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 949299, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 5764136, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 4286484, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 2571362, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 2683761, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 4808443, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 6508546, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 4755375, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 7893281, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 46904191, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 31256851, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 6600620, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 32233968, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 27978221, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 27416186, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 27924301, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 3130743, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 653525, 'subcategory': None},
#  {'level': 1, 'maincategoryid': 45, 'pageid': 35898322, 'subcategory': None}]

# %%
select_stmt = """
SELECT count(*) FROM PAGE_INFO A LEFT OUTER JOIN PAGE_DATA B ON A.PAGEID = B.PAGEID WHERE B.PAGEID IS NULL ;
"""
cursor.execute(select_stmt)
cursor.fetchall()
# Out:
# [{'count': 0}]

# %%
select_stmt = """
SELECT count(*) FROM page_info  limit 10;
"""
cursor.execute(select_stmt)
cursor.fetchall()
# Out:
# [{'count': 3876}]

# %%
clear_table = """
BEGIN;
DELETE FROM PAGE_INFO;
COMMIT;
DELETE FROM CATEGORY_DATA;
COMMIT;
"""
cursor.execute(clear_table)

# %%
#get_wikipedia_page_ids('Botany',3)

# %%
select_stmt = """
SELECT count(*) FROM CATEGORY_DATA;
"""
cursor.execute(select_stmt)
cursor.fetchall()

# %%
select_stmt = """
SELECT * FROM CATEGORY_INFO A, PAGE_INFO B where A.PAGEID = B.PAGEID AND B.title = 'Deeplearning4j';
"""
cursor.execute(select_stmt)
cursor.fetchall()

# %%
def get_wikipedia_page_text():
    select_stmt = """
            SELECT A.PAGEID,A.TITLE FROM PAGE_INFO A LEFT OUTER JOIN PAGE_DATA B ON A.PAGEID = B.PAGEID WHERE B.PAGEID IS NULL;
        """
    cursor.execute(select_stmt)
    result = cursor.fetchall()
    for item in result:
        pageid = item['pageid']
        title = item['title']
        base_url = 'https://en.wikipedia.org/w/api.php'
        action = '?action=query'
        parameter2 = '&format=json&prop=extracts&explaintext=True&pageids=' + str(pageid)
        rich_url = base_url+action+parameter2
        response_url = requests.get(rich_url)
        r_text = response_url.json()['query']['pages'][str(pageid)]['extract']
        r_text = r_text.replace("'", '"')
        r_text = cleaner(r_text)
        insert_stmt = """
                    BEGIN;
                    INSERT INTO PAGE_DATA VALUES ({},'{}', '{}');
                    COMMIT;
        """.format(pageid, title, r_text)
        cursor.execute(insert_stmt)

# %%
get_wikipedia_page_text()

# %%
connection, cursor = db.connect_to_db()

# %%
select_stmt = """
SELECT distinct(pageid), count(*)  FROM PAGE_DATA group by pageid order by count(*) desc ;
"""
cursor.execute(select_stmt)
cursor.fetchall()
# Out:
# [{'count': 1, 'pageid': 2764},
#  {'count': 1, 'pageid': 2923},
#  {'count': 1, 'pageid': 1950623},
#  {'count': 1, 'pageid': 1950870},
#  {'count': 1, 'pageid': 1953627},
#  {'count': 1, 'pageid': 1954092},
#  {'count': 1, 'pageid': 1956402},
#  {'count': 1, 'pageid': 1963417},
#  {'count': 1, 'pageid': 1966364},
#  {'count': 1, 'pageid': 1966797},
#  {'count': 1, 'pageid': 1966814},
#  {'count': 1, 'pageid': 1969357},
#  {'count': 1, 'pageid': 1970375},
#  {'count': 1, 'pageid': 1971534},
#  {'count': 1, 'pageid': 1971849},
#  {'count': 1, 'pageid': 1977119},
#  {'count': 1, 'pageid': 1977801},
#  {'count': 1, 'pageid': 1978642},
#  {'count': 1, 'pageid': 1982696},
#  {'count': 1, 'pageid': 1984019},
#  {'count': 1, 'pageid': 1986673},
#  {'count': 1, 'pageid': 1988772},
#  {'count': 1, 'pageid': 1993175},
#  {'count': 1, 'pageid': 1994676},
#  {'count': 1, 'pageid': 1995918},
#  {'count': 1, 'pageid': 2006097},
#  {'count': 1, 'pageid': 2006843},
#  {'count': 1, 'pageid': 2007748},
#  {'count': 1, 'pageid': 2008884},
#  {'count': 1, 'pageid': 2009024},
#  {'count': 1, 'pageid': 2011728},
#  {'count': 1, 'pageid': 2016186},
#  {'count': 1, 'pageid': 2018323},
#  {'count': 1, 'pageid': 2022939},
#  {'count': 1, 'pageid': 2029470},
#  {'count': 1, 'pageid': 2030607},
#  {'count': 1, 'pageid': 2040304},
#  {'count': 1, 'pageid': 2041402},
#  {'count': 1, 'pageid': 2043483},
#  {'count': 1, 'pageid': 2045314},
#  {'count': 1, 'pageid': 2052309},
#  {'count': 1, 'pageid': 2052325},
#  {'count': 1, 'pageid': 2053131},
#  {'count': 1, 'pageid': 2055358},
#  {'count': 1, 'pageid': 2057290},
#  {'count': 1, 'pageid': 2058605},
#  {'count': 1, 'pageid': 2061486},
#  {'count': 1, 'pageid': 2066117},
#  {'count': 1, 'pageid': 2066130},
#  {'count': 1, 'pageid': 2070605},
#  {'count': 1, 'pageid': 2071878},
#  {'count': 1, 'pageid': 2077488},
#  {'count': 1, 'pageid': 2078819},
#  {'count': 1, 'pageid': 2085584},
#  {'count': 1, 'pageid': 2088675},
#  {'count': 1, 'pageid': 2090057},
#  {'count': 1, 'pageid': 2093407},
#  {'count': 1, 'pageid': 2101109},
#  {'count': 1, 'pageid': 2110074},
#  {'count': 1, 'pageid': 2112342},
#  {'count': 1, 'pageid': 2112462},
#  {'count': 1, 'pageid': 2112617},
#  {'count': 1, 'pageid': 2125256},
#  {'count': 1, 'pageid': 2127621},
#  {'count': 1, 'pageid': 2139778},
#  {'count': 1, 'pageid': 2139847},
#  {'count': 1, 'pageid': 2143999},
#  {'count': 1, 'pageid': 2146505},
#  {'count': 1, 'pageid': 2150852},
#  {'count': 1, 'pageid': 2155746},
#  {'count': 1, 'pageid': 2156814},
#  ...]

# %%
select_stmt = """
SELECT count(*) FROM PAGE_DATA;
"""
cursor.execute(select_stmt)
cursor.fetchall()
# Out:
# [{'count': 0}]

# %%
clear_table = """
BEGIN;
DELETE FROM PAGE_DATA;
COMMIT;

"""
cursor.execute(clear_table)
